# %%
import torch
import numpy as np
import QuSelfAttn as Q

# %%
qc = Q.Circuit(3)

# %%
# qc.rx(2,0.5)

# %%
# qc.ry(1,1)

# %%
# qc.rz(1,1)

# %%
# qc.Hcz(1,1)

# %%
# qc.z_gate(1)

# %%
# qc.rxx(1,1)

# %%
qc.cnot(1,0.5)

# %%
qc.show_gates()
# Out:
#  gate in sequence is : [{'gate': 'rx', 'theta': 0.5, 'which_qubit': 2}, {'gate': 'ry', 'theta': 1, 'which_qubit': 1}, {'gate': 'rz', 'theta': 1, 'which_qubit': 1}, {'gate': 'I', 'theta': None, 'which_qubit': 1}, {'gate': 'Z', 'theta': None, 'which_qubit': 1}, {'gate': 'Z', 'theta': None, 'which_qubit': 1}, {'gate': 'rx', 'theta': 1, 'which_qubit': 1}, {'gate': 'rx', 'theta': 1, 'which_qubit': 2}, {'gate': 'rx', 'theta': 1, 'which_qubit': 1}, {'gate': 'rx', 'theta': 1, 'which_qubit': 2}, {'gate': 'I', 'theta': None, 'which_qubit': 1}, {'gate': 'X', 'theta': None, 'which_qubit': 0.5}]

# %%
qc.gate_list
# Out:
# [{'gate': 'rx', 'theta': 0.5, 'which_qubit': 2},
#  {'gate': 'ry', 'theta': 1, 'which_qubit': 1},
#  {'gate': 'rz', 'theta': 1, 'which_qubit': 1},
#  {'gate': 'I', 'theta': None, 'which_qubit': 1},
#  {'gate': 'Z', 'theta': None, 'which_qubit': 1},
#  {'gate': 'Z', 'theta': None, 'which_qubit': 1},
#  {'gate': 'rx', 'theta': 1, 'which_qubit': 1},
#  {'gate': 'rx', 'theta': 1, 'which_qubit': 2},
#  {'gate': 'rx', 'theta': 1, 'which_qubit': 1},
#  {'gate': 'rx', 'theta': 1, 'which_qubit': 2},
#  {'gate': 'I', 'theta': None, 'which_qubit': 1},
#  {'gate': 'X', 'theta': None, 'which_qubit': 0.5}]

# %%
qc.read_gate()
# Out:
#  index: 0
#  gate_list:{'gate': 'rx', 'theta': 0.5, 'which_qubit': 2}
#  gate_matrix: tensor([[0.9689+0.0000j, 0.0000-0.2474j],
#         [0.0000-0.2474j, 0.9689+0.0000j]])
#  circuit_matrix: tensor([[0.9689+0.0000j, 0.0000-0.2474j, 0.0000+0.0000j, 0.0000+0.0000j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000-0.2474j, 0.9689+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000+0.0000j, 0.0000+0.0000j, 0.9689+0.0000j, 0.0000-0.2474j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000+0.0000j, 0.0000+0.0000j, 0.0000-0.2474j, 0.9689+0.0000j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j,
#          0.9689+0.0000j, 0.0000-0.2474j, 0.0000+0.0000j, 0.0000+0.0000j],
# ...

# %%
qc.U
