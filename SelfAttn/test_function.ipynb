# %%
import torch
import numpy as np
import QuSelfAttn as Q

# %%
qc = Q.Circuit(3)

# %%
qc.rx(2,0.5)

# %%
qc.rx(1,1)

# %%
qc.rx(1,0.5)

# %%
qc.rz(2,1)

# %%
qc.ry(2,1)

# %%
qc.show_gates()
# Out:
#  gate in sequence is : [{'gate': 'rx', 'theta': 0.5, 'which_qubit': 2}, {'gate': 'rx', 'theta': 1, 'which_qubit': 1}, {'gate': 'rx', 'theta': 0.5, 'which_qubit': 1}, {'gate': 'rz', 'theta': 1, 'which_qubit': 2}, {'gate': 'ry', 'theta': 1, 'which_qubit': 2}]

# %%
qc.gate_list
# Out:
# [{'gate': 'rx', 'theta': 0.5, 'which_qubit': 2},
#  {'gate': 'rx', 'theta': 1, 'which_qubit': 1},
#  {'gate': 'rx', 'theta': 0.5, 'which_qubit': 1},
#  {'gate': 'rz', 'theta': 1, 'which_qubit': 2},
#  {'gate': 'ry', 'theta': 1, 'which_qubit': 2}]

# %%
qc.read_gate()
# Out:
#  index: 0
#  gate_list:{'gate': 'rx', 'theta': 0.5, 'which_qubit': 2}
#  gate_matrix: tensor([[0.9689+0.0000j, 0.0000-0.2474j],
#         [0.0000-0.2474j, 0.9689+0.0000j]])
#  circuit_matrix: tensor([[0.9689+0.0000j, 0.0000-0.2474j, 0.0000+0.0000j, 0.0000+0.0000j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000-0.2474j, 0.9689+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000+0.0000j, 0.0000+0.0000j, 0.9689+0.0000j, 0.0000-0.2474j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000+0.0000j, 0.0000+0.0000j, 0.0000-0.2474j, 0.9689+0.0000j,
#          0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j],
#         [0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j, 0.0000+0.0000j,
#          0.9689+0.0000j, 0.0000-0.2474j, 0.0000+0.0000j, 0.0000+0.0000j],
# ...

# %%
qc.U
# Out:
# tensor([[ 0.5044-0.2221j, -0.3744-0.3024j, -0.2069-0.4699j, -0.2817+0.3488j,
#           0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j],
#         [ 0.3744-0.3024j,  0.5044+0.2221j, -0.2817-0.3488j,  0.2069-0.4699j,
#           0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j],
#         [-0.2069-0.4699j, -0.2817+0.3488j,  0.5044-0.2221j, -0.3744-0.3024j,
#           0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j],
#         [-0.2817-0.3488j,  0.2069-0.4699j,  0.3744-0.3024j,  0.5044+0.2221j,
#           0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j],
#         [ 0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,
#           0.5044-0.2221j, -0.3744-0.3024j, -0.2069-0.4699j, -0.2817+0.3488j],
#         [ 0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,
#           0.3744-0.3024j,  0.5044+0.2221j, -0.2817-0.3488j,  0.2069-0.4699j],
# ...
